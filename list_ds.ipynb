# %% [markdown]
# PYTHON DATA STRUCTURE

# %%
LIST DATA STRUCTURE

# %%
#Data Type only one value declare to variable
#In Data structure multiple value are assigned to variable

# %%
l=[] #list always in square braces []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
a=[]
a.append(20)
a.append(30) #append function is added object to end
a
# Out:
# [20, 30]

# %%
len(a)
# Out:
# 2

# %%
a.append(30) #duplicates are allowed
a.append(40)
a.append(50) 
a
# Out:
# [20, 30, 30, 40, 50]

# %%
l1 = [10,2.3,2+5j,'nit',[4,5,6]]
l1
# Out:
# [10, 2.3, (2+5j), 'nit', [4, 5, 6]]

# %%
len(l1)
# Out:
# 5

# %%
len(a)
# Out:
# 5

# %%
l2 = l1.copy() #copy function is used store the varlues of that variable
l2
# Out:
# [10, 2.3, (2+5j), 'nit', [4, 5, 6]]

# %%
len(l2)
# Out:
# 5

# %%
print(id(a))
print(id(l1))
print(id(l2))
# Out:
# 1828055766656
# 1828055787776
# 1828061847936

# %%
l2.clear() #Clear function is used to remove the values, it makes the list empty
# Out:
# []

# %%
len(l2)
# Out:
# 0

# %%
del l2 #Del function is used to delete the variable
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 del l2 #Del function is used to delete the variable
#       2 l2
#
# NameError: name 'l2' is not defined

# %%
a.count(20) # count is used to count of  a particular element
# Out:
# 1

# %%
a=[1,2,3] #Extend function is used to join the variable values
b=[4,5,6] 
a.extend(b)
a
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l3=[]
l3
# Out:
# []

# %%
l3.extend(b)
l3
# Out:
# [4, 5, 6]

# %%
print(l1)
print(l2)
print(a)
print(b)
print(l3)
# Out:
# [10, 2.3, (2+5j), 'nit', [4, 5, 6]]
# [1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6]
# [1, 2, 3, 4, 5, 6]
# [4, 5, 6]
# [4, 5, 6]

# %%
#list slicing
b[0]
# Out:
# 4

# %%
b[0]=25 # we can change the value in list that means list is mutable 
b
# Out:
# [25, 50, 6]

# %%
b[-2]=50
b
# Out:
# [25, 50, 6]

# %%
a.index(1) # this function is used to find the index value of element in list
# Out:
# 0

# %%
l2.index(2) # if we have duplicate values it considers first value only
# Out:
# 1

# %%
#insert () function is used to insert the value before the mentioned index
b.insert(2,2.5)
b
# Out:
# [25, 50, 2.5, 2.5, 6]

# %%
b.insert(4,10)
b
# Out:
# [25, 50, 2.5, 2.5, 10, 6]

# %%
# pop function removes the last element
b.pop()
b
# Out:
# [25, 50, 2.5, 2.5, 10]

# %%
b.pop(2)
b
# Out:
# [25, 50, 2.5, 10]

# %%
#reverse function is used to reverse the value , reverse is not sorting
b.reverse()
b
# Out:
# [10, 2.5, 50, 25]

# %%
#sorting is used to order 
b.sort(reverse=False) #descending order
b
# Out:
# [2.5, 10, 25, 50]

# %%
b.sort(reverse=True) #Ascending order
b
# Out:
# [50, 25, 10, 2.5]

# %%
#list membership 
50 in b
# Out:
# True

# %%
100 in b
# Out:
# False

# %%
d = [10,'nit',[10,20],65]
d.remove(10)
d
# Out:
# ['nit', [10, 20], 65]

# %%
d=[23,'Fsds',29,[29,30],11]
d[3].remove(29)
d
# Out:
# [23, 'Fsds', 29, [30], 11]
