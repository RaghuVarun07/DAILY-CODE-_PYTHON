# %% [markdown]
# SET

# %%
# SET is defined in {}
s ={}
s
# Out:
# {}

# %%
type(s) # If we give empty {} it defaulty considered as dict
# Out:
# dict

# %%
# If we neeed empty set 
s=set()
s
# Out:
# set()

# %%
type(s)
# Out:
# set

# %%
s1 = {24,45,67,55,3,1,45} # Automatically sorting is considered when user pass the same data type
s1
# Out:
# {1, 3, 24, 45, 55, 67}

# %%
# There are multiple functions in SET (18)
s1.add(100) # if data types are same the element will add to set in order
s1
# Out:
# {1, 3, 24, 45, 55, 67, 100}

# %%
s1.add(0)
s1
# Out:
# {0, 1, 3, 24, 45, 55, 67, 100}

# %%
s2={1+2j, 'nit', 23 , True, 2.0}
s2
# Out:
# {(1+2j), 2.0, 23, True, 'nit'}

# %%
s2.add('.net') #if data types are different the element will be added randomly
s2
# Out:
# {(1+2j), '.net', 2.0, 23, True, 'nit'}

# %% [markdown]
# POP #(pop should not work with index)

# %%
s2.pop(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s2.pop(0)
#
# TypeError: set.pop() takes no arguments (1 given)

# %%
# Indexing and Slicing is not allowed in set{}

# %%
s2.pop() #it removes a random value
# Out:
# 'nit'

# %%
s2.remove(2.0)
s2
# Out:
# {(1+2j), 23, True}

# %%
s2.discard(23)
s2
# Out:
# {(1+2j), True}

# %%
s2.discard(100) # If element is not available it doesn't gives error
s2
# Out:
# {(1+2j), True}

# %%
s2.remove(100) # If element is not available it gives error
s2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 s2.remove(100)
#       2 s2
#
# KeyError: 100

# %%
# In set duplicates are not allowed

# %% [markdown]
# SET OPERATIONS

# %%
# Union #Intersect # Difference # Symmetric_difference #symmetric_difference_update #Intersection_update

# %%
set1 = { 1,2,3,4,5}
set2 = {4,5,6}
set3 = {6,7,8,9}
set1.union(set2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# Union is represented in "|"
set2|set3
# Out:
# {4, 5, 6, 7, 8, 9}

# %%
set1|set2|set3
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
