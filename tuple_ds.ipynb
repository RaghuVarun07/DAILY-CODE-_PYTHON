# %% [markdown]
# TUPLE

# %%
# Tuple reperesnts in ()
t = () #Empty tuple
type(t)
# Out:
# tuple

# %%
t1 = (10,20,30) # Tuple with integers
t1
# Out:
# (10, 20, 30)

# %%
# There are 2 functions in Tuple
# 1. Count
# 2. Index
t1.count(10)
# Out:
# 1

# %%
t2 = ('raghu','sai','varun') #Tuple with Strings
t2
# Out:
# ('raghu', 'sai', 'varun')

# %%
t3 = (2.5, 4.0, 6.3, 8.8) # Tuple with Float Values
t3
# Out:
# (2.5, 4.0, 6.3, 8.8)

# %%
t4 = ((20,45),2.0, 45,(22,30)) #nested tuples
t4
# Out:
# ((20, 45), 2.0, 45, (22, 30))

# %%
t5 = ('Raghu', 23,  86.66, 2+5j) # Mixed type  of data types
t5
# Out:
# ('Raghu', 23, 86.66, (2+5j))

# %%
len(t5) #Length of tuple
# Out:
# 4

# %%
t2[0]
# Out:
# 'raghu'

# %%
t4[3][0]
# Out:
# 22

# %%
t5[:3]
# Out:
# ('Raghu', 23, 86.66)

# %%
tup = ( 'Data Science', 'Python', 'Pycharm', 'Jupyter', 'Numpy')
tup
# Out:
# ('Data Science', 'Python', 'Pycharm', 'Jupyter', 'Numpy')

# %%
tup[:3]
# Out:
# ('Data Science', 'Python', 'Pycharm')

# %%
tup[0:2] #Return first two items
# Out:
# ('Data Science', 'Python')

# %%
tup[-3:] # Return last 3 items
# Out:
# ('Pycharm', 'Jupyter', 'Numpy')

# %%
tup[-1:] # Return last item
# Out:
# ('Numpy',)

# %%
tup[:] # Return whole tuple
# Out:
# ('Data Science', 'Python', 'Pycharm', 'Jupyter', 'Numpy')

# %% [markdown]
# # Tuple is immutable
# # In tuples we can't change the values
# # It allows duplicates values allso

# %%
tup[0] = 'DS'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 tup[0] = 'DS'
#
# TypeError: 'tuple' object does not support item assignment

# %%
del tup[0] # We can't delete tuple values
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 del tup[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %%
del tup #Delete Whole tuple is possible

# %%
tup()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 tup()
#
# NameError: name 'tup' is not defined

# %%
tup = ( 'Data Science', 'Python', 'Pycharm', 'Jupyter', 'Numpy')
tup
# Out:
# ('Data Science', 'Python', 'Pycharm', 'Jupyter', 'Numpy')

# %%
for i in (tup):
    print(i)
# Out:
# Data Science
# Python
# Pycharm
# Jupyter
# Numpy

# %%
tup
# Out:
# ('Data Science', 'Python', 'Pycharm', 'Jupyter', 'Numpy')

# %% [markdown]
# Tuple Membership

# %%
'Python' in tup
# Out:
# True

# %%
'Pycharm' in tup
# Out:
# True

# %%
'Java' in tup
# Out:
# False

# %%
if 'Numpy' in tup:
    print(" Numpy is present in the tuple")
else:
    print("Numpy is not present in the tuple")
# Out:
#  Numpy is present in the tuple

# %%
tup.index('Data Science')
# Out:
# 0

# %%
tup.index('Pycharm')
# Out:
# 2
