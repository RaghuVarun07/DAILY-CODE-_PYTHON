# %%
w="RaghuSaiVarun"
w
# Out:
# 'RaghuSaiVarun'

# %%
w[0:14:2]
# Out:
# 'RguaVrn'

# %%
w[1:8:3]
# Out:
# 'aui'

# %%
w[::-1]
# Out:
# 'nuraViaSuhgaR'

# %%
w[::-2]
# Out:
# 'nrVaugR'

# %%
#scalar [4]
#vector is a collection of scalars[ matrix created by numpy library]
#tensor is a collection of vector [ Tensor created by pytorch library]

# %%
car() #car fuction without argument
car('audi','tata') #car function with two arguments

# %% [markdown]
# PYTHON TYPE CASTING

# %%
#All other data types to integer
int(2.0)
# Out:
# 2

# %%
#tytpe casting doesnot allow more than one argument
int(2.0,98.6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 #tytpe casting doesnot allow more than one argument
# ----> 2 int(2.0,98.6)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int('10')
# Out:
# 10

# %%
#text string to intger is not valid only number string is valid
int('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 #text string to intger is not valid only number string is valid
# ----> 2 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
#complex to integer type casting is not possible
int(3+2j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 #complex to integer type casting is not possible
# ----> 2 int(3+2j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %% [markdown]
# OTHER DATA TYPES TO FLOAT

# %%
float(2)
# Out:
# 2.0

# %%
float(True)
# Out:
# 1.0

# %%
float('Sai')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 float('Sai')
#
# ValueError: could not convert string to float: 'Sai'

# %%
float('10')
# Out:
# 10.0

# %%
float(9+10j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 float(9+10j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
 OTHER DATA TYPES TO BOOLEAN

# %%
bool(10)
# Out:
# True

# %%
bool(0)
#except o value remaining all are true
# Out:
# False

# %%
bool('Sai')
# Out:
# True

# %%
bool(2+3j)
# Out:
# True

# %%
bool( )#empty space
# Out:
# False
