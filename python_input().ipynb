# %%
math.sqrt(25)
#here we get error becoz we didn't defined the math
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 math.sqrt(25)
#
# NameError: name 'math' is not defined

# %%
#math is a module which is used for math functions
import math
math.sqrt(25)
# Out:
# 5.0

# %%
round(math.sqrt(25))
# Out:
# 5

# %%
math.ceil(22.3)
#if the value is float it prints the next number
# Out:
# 23

# %%
math.floor(22.1)
# if the value is float then it prints before number
# Out:
# 22

# %%
math.pi
# Out:
# 3.141592653589793

# %%
pi=2.50
pi
#In python there is no constant values
# Out:
# 2.5

# %%
pow(2,3)
# Out:
# 8

# %%
# help() it used to know about python

# %%
m.sqrt(25)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 m.sqrt(25)
#
# NameError: name 'm' is not defined

# %%
import math as m
#here we can change the module name by using as keyword
m.sqrt(25)
# Out:
# 5.0

# %%
from math import sqrt
# from keyword used to import single function

# %%
# for multiple function we use the * it imports all functions in a module
from math import *
math.pow(2,3)
# Out:
# 8.0

# %%
input()
# Out:
#  hello
# 'hello'

# %%
a=input("Enter a number : ")
b=input("Enter a number : ")
c= a+b
print(c)
#input() always understand as string if we need in int we use the int()
# Out:
# Enter a number :  20
# Enter a number :  03
# 2003

# %%
A=int(input("Number 1 : "))
B=int(input("number 2 : "))
C = A+B
print(C)
# Out:
# Number 1 :  20
# number 2 :  03
# 23

# %%
statement = input("Enter a string : ")
statement
# Out:
# Enter a string :  Learning Fullstack Data Science
# 'Learning Fullstack Data Science'

# %%
statement=input("Enter a string : ")[9:]
statement
# Out:
# Enter a string :  Learning Fullstack Data Science
# 'Fullstack Data Science'
