# %%
# Syntax : Variable = Value
# Variable == object == identifiers
# Value= Data Types
Name = "Raghu"
Name
# Out:
# 'Raghu'

# %%
# Variable Can't Start with numbers but it ends with number
Subject1 = 98
Subject1
# Out:
# 98

# %%
# Case Sensitive 
Course = "FSDS"
Course
# If we try to print COURSE we will get error
# Out:
# 'FSDS'

# %%
# Special Characters are not allowed except " _ "
_varun = "Data Scientist"
_varun
# Out:
# 'Data Scientist'

# %%
#Keywords are not defined as "VARIABLES"
# we get error if we did 
# There are 35 Keywords in Python
if = 100
if
# Out:
#   Cell In[18], line 4
#     if = 100
#        ^
# SyntaxError: invalid syntax

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
Class="10:30 AM"
Class
# Out:
# '10:30 AM'

# %%
# "_" prints previous values
_
# Out:
# '10:30 AM'
