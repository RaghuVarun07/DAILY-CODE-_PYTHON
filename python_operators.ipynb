# %% [markdown]
# OTHER DATA TYPES TO COMPLEX

# %%
complex(2)
# Out:
# (2+0j)

# %%
complex("varun")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 complex("varun")
#
# ValueError: complex() arg is a malformed string

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(2.5)
# Out:
# (2.5+0j)

# %%
complex(4.5,6.7)
# Out:
# (4.5+6.7j)

# %%
complex(24,4.7)
# Out:
# (24+4.7j)

# %%
complex(10,20,30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 complex(10,20,30)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 complex('10','20')
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex(10,'20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 complex(10,'20')
#
# TypeError: complex() second arg can't be a string

# %%
complex('20',30)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 complex('20',30)
#
# TypeError: complex() can't take second arg if first is a string

# %% [markdown]
# OTHER DATA TYPES TO STRING

# %%
str(54)
# Out:
# '54'

# %%
str(3.5)
# Out:
# '3.5'

# %%
str(True)
# Out:
# 'True'

# %%
str(2+3j)
# Out:
# '(2+3j)'

# %%
str(10,3.5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 str(10,3.5)
#
# TypeError: str() argument 'encoding' must be str, not float

# %%
str(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 str(10,20)
#
# TypeError: str() argument 'encoding' must be str, not int

# %% [markdown]
# PYTHON OPERATORS

# %%
#ARITHMETIC OPERATOR
#ASSIGNMENT OPERATOR
#RELATIONAL OPERATOR
#LOGICAL OPERATOR
#UNARY OPERATOR

# %%
ARITHMETIC OPERATOR

# %%
x,y=4,5

# %%
x+y
# Out:
# 9

# %%
x-y
# Out:
# -1

# %%
x%y #remainder
# Out:
# 4

# %%
x/y
# Out:
# 0.8

# %%
x//y
# Out:
# 0

# %%
x*y
# Out:
# 20

# %%
x**y
# Out:
# 1024

# %% [markdown]
# ASSIGNMENT OPERATOR

# %%
#[+=,-=,*=,/=,//=,%=, **=]
x=2

# %%
x+=2
x
# Out:
# 4

# %%
x=8
x-=2
x
# Out:
# 6

# %%
x*=2
x
# Out:
# 12

# %%
x/=3
x
# Out:
# 1.3333333333333333

# %%
x=16
x//=4
x
# Out:
# 4

# %%
x%=2
x
# Out:
# 0

# %%
x=5
x**=3
x
# Out:
# 125

# %% [markdown]
# UNARY OPERATOR

# %%
#[ in  this we use only one operator i.e minus called as negation]
a=200
-a
# Out:
# -200

# %% [markdown]
# RELATIONAL OPERATOR

# %%
#[>=, <=, == ,!=]

# %%
a=25
b=20
a>b
# Out:
# True

# %%
a<b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
a>=b
# Out:
# True

# %%
b>=a
# Out:
# False

# %%
a="Varun"
b="Sai"
a>b
# Out:
# True

# %% [markdown]
# LOGICAL OPERATOR

# %%
# [ AND , OR, NOT]

# %%
a=16
b=4
a>b and b<a
# Out:
# True

# %%
a<b or a>b
# Out:
# True

# %%
x=True
not x
# Out:
# False

# %%
python = 97
java = 95
total = python+java
print("The total marks i got in java and python is :",total)
# Out:
# The total marks i got in java and python is : 192

# %%
num1 = 25
num2 = 75
add= num1+num2
print("The addition of",num1,"and",num2,"is",total)
# Out:
# The addition of 25 and 75 is 192
