# %%
# String must declare with ' ' | " " | ''' '''|
# ' ' & " " are used when we have single line comment
# ''' ''' are used when we have multi line comment
' Myslef Raghu Sai Varun
I am very excited to learn
Full Stack Data Science Course'
# Out:
#   Cell In[2], line 4
#     ' Myslef Raghu Sai Varun
#     ^
# SyntaxError: unterminated string literal (detected at line 4)

# %%
" Myslef Raghu Sai Varun
I am very excited to learn
Full Stack Data Science Course"
# Out:
#   Cell In[3], line 1
#     " Myslef Raghu Sai Varun
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
''' Myslef Raghu Sai Varun
I am very excited to learn
Full Stack Data Science Course'''
# Out:
# ' Myslef Raghu Sai Varun\nI am very excited to learn\nFull Stack Data Science Course'

# %%
z = "Data Science"
z
# Out:
# 'Data Science'

# %%
z[1]
# Out:
# 'a'

# %%
#Python Index begins with '0'
# Indexing 2 types :
# Forward Indexing starts with 0  from left
# Backward Indexing starts with -1 from right
z[-3]
# Out:
# 'n'

# %%
#STRING SLICING 
z
# Out:
# 'Data Science'

# %%
z[:] #prints all the string
# Out:
# 'Data Science'

# %%
z[0:]# print from index 0 to last
# Out:
# 'Data Science'

# %%
z[5:9] #print from index 5 to index 8 (n-1)
# Out:
# 'Scie'

# %%
z[:12] # starts from 0th index to 11th index
# Out:
# 'Data Science'
