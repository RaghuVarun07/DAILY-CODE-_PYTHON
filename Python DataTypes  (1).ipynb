# %%
#DATA TYPES
#INTEGER
#FLOAT
#STRING
#BOOLEAN
#COMPLEX

# %%
#Integer (int)
a = 45
type(a)
# Out:
# int

# %%
#Float (float)
f =99.99
type(f)
# Out:
# float

# %%
#String (str)
goal = "Coading"
type(goal)
# Out:
# str

# %%
#Boolean (bool)
True
type(True)
# Out:
# bool

# %%
# if we add bool values we get the binary values
True+True
# Out:
# 2

# %%
#Complex (Except python any other language contains Complex Data Type
#complex has two parts 1.real part 2.imaginary part
c = 10+20j # ( 10 is real part, 20 is imaginary part and j is the square root of -1)
#In python if we call any function we use "."
print(c)
print(c.real) # if we need real part only
print(c.imag) # if we need imaginary part only
# Out:
# (10+20j)
# 10.0
# 20.0

# %%
#Functions end with ()
car="bmw" #bmw is called as arguments or parameters
car
# Out:
# 'bmw'

# %%
#FLOAT accepts letter e or E
f= 2.1e0
f
# Out:
# 2.1
