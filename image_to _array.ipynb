# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image # PIL python image library

# %%
image = Image.open(r"C:\Users\RAGHU SAI VARUN\Desktop\tiger.jpg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=625x350>

# %%
print(type(image))
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>

# %%
arr = np.asarray(image)  # It converts image into Numpy array 
arr
# Out:
# array([[[ 58,  41,  25],
#         [ 70,  53,  37],
#         [ 87,  70,  54],
#         ...,
#         [  5,   6,  10],
#         [  5,   6,  10],
#         [  5,   6,  10]],
#
#        [[ 56,  39,  23],
#         [ 66,  49,  33],
#         [ 82,  65,  49],
#         ...,
#         [  5,   6,  10],
#         [  5,   6,  10],
#         [  5,   6,  10]],
#
#        [[ 54,  37,  21],
#         [ 62,  45,  29],
#         [ 75,  58,  42],
#         ...,
#         [  5,   6,  10],
#         [  5,   6,  10],
#         [  5,   6,  10]],
#
#        ...,
#
#        [[238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238],
#         ...,
#         [234, 234, 234],
#         [234, 234, 234],
#         [233, 233, 233]],
#
#        [[238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238],
#         ...,
#         [234, 234, 234],
#         [234, 234, 234],
#         [233, 233, 233]],
#
#        [[238, 238, 238],
#         [238, 238, 238],
#         [238, 238, 238],
# ...

# %%
plt.imshow(arr)
plt.show()

# %%
arr.shape #It represents dimensions
# Out:
# (350, 625, 3)
